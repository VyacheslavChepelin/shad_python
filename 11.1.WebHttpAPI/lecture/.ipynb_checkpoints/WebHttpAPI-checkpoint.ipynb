# %% [markdown]
# <center>
#     <img src="https://upload.wikimedia.org/wikipedia/commons/a/a8/%D0%9B%D0%9E%D0%93%D0%9E_%D0%A8%D0%90%D0%94.png" width=500px/>
#     <font>Python 2025</font><br/>
#     <br/>
#     <br/>
#     <b style="font-size: 2em">Web, HTTP, API</b><br/>
#     <br/>
#     <font>Вячеслав Жуков</font><br/>
# </center>

# %% [markdown]
# ## План лекции
#
# * Устройство компьютерных сетей (25 min)
# * Сети в Python; Web Scraping (25 min)
# * APIs (30 min)

# %% [markdown]
# # Устройство компьютерных сетей

# %% [markdown]
# - Обмен данными по сети устроен многоуровнево – от тока в проводах до картинки в браузере
# - Для того что бы использовать сеть, как правило, не требуется хорошо разбираться во всех уровнях

# %% [markdown]
# ## Сеть на низком уровне
#
# Если хочется разобраться, то ["Сети для самых маленьких"](https://linkmeup.gitbook.io/sdsm/) | [[оно же на habr]](https://habr.com/ru/post/134892/)
#
# - Сетевая карта (NIC) — это «дверь» в сеть. Она отправляет и принимает биты по Ethernet или Wi‑Fi.
# - Она работает с «кадрами» на канальном уровне и имеет уникальный аппаратный идентификатор — MAC‑адрес.
# - ОС взаимодействует с сетевым адаптером через драйвер; адаптер обрабатывает физические (электрические/беспроводные) сигналы и передаёт кадры вверх в ОС.
#
# <div><center>
# <img style="max-width: 800px" src="./images/Components-of-a-computer-network-2-4.png" />
# <div><a href="https://www.researchgate.net/figure/Components-of-a-computer-network-2-4_fig1_386154909">image credit</a></div>
# </center></div>

# %% [markdown]
# ## Сетевые модели OSI и TCP/IP

# %% [markdown]
# 1. OSI эталонная 7-уровневая модель - теоретическая
# 2. TCP/IP - практическая 4-уровневая - на ней работает интернет
#
# [Подробнее про стеки и протоколы](https://zametkinapolyah.ru/kompyuternye-seti/stek-protokolov-tcp-ip.html)
#
# <div><center>
# <img src="./images/03-Сравнение-моделей-OSI-7-и-TCP-IP.png" />
# <div><a href="https://zametkinapolyah.ru/kompyuternye-seti/stek-protokolov-tcp-ip.html">image credit</a></div>
# </center></div>

# %% [markdown]
# ### IPv4 vs IPv6

# %% [markdown]
# <div><center>
# <img style="max-width: 800px" src="./images/ipv4-ipv6.png" />
# <div><a href="https://www.networkacademy.io/ccna/ipv6/what-is-ipv6">image credit</a></div>
# </center></div>

# %% [markdown]
# <div><center>
# <img style="max-width: 800px"  src="./images/TCP_IP.svg" />
#     <div><a href="https://www.slideserve.com/dalmar/ipv4-addresses-powerpoint-ppt-presentation">image credit</a></div>
# </center></div>

# %% [markdown]
# ### TCP vs UDP
# - UDP просто посылает сообщения и не заботится о надёжности доставки или порядке прихода сообщений
# - TCP выполняет "рукопожатие" между клиентами и может гарантировать надёжность доставки и порядок прихода сообщений

# %% [markdown]
# <div><center>
# <img style="max-width: 800px"  src="./images/TCP_UDP.png" />
#     <div><a href="https://www.freecodecamp.org/news/why-you-should-run-your-game-servers-independently-from-your-chat-3263b4b9548e/">image credit</a></div>
# </center></div>

# %% [markdown]
# #### Порты
#
# - 16-битное число, позволяющее идентифицировать конкретный процесс на машине с одним и тем же IP-адресом
#
# <div><center>
# <img style="max-width: 800px" src="./images/TCP_ports.png" />
#     <div><a href="https://tpbabparn.medium.com/cs-for-non-tech-network-infrastructure-security-zone-%E0%B9%84%E0%B8%97%E0%B8%A2-91ea1cf2cef5">image credit</a></div>
# </center></div>

# %% [markdown]
# ## URL: Uniform Resource Locator
#
# <div><center>
# <img style="max-width: 800px" src="./images/url-diag.PNG" />
#     <div><a href="https://www.geeksforgeeks.org/computer-networks/components-of-a-url/">image credit</a></div>
# </center></div>
#
# URL идентифицирует ресурс по его местоположению, и описывает как обратиться к этому ресурсу.
#
# Есть много разных примеров URL:
# ```
# - ftp://ftp.is.co.za/rfc/rfc1808.txt
# - http://www.ietf.org/rfc/rfc2396.txt
# - ldap://[2001:db8::7]/c=GB?objectClass?one
# - mailto:John.Doe@example.com
# - tel:+1-816-555-1212
# - telnet://192.0.2.16:80/
# ```
#
# Этот раздел:
# ```
# http://localhost:8889/lab/tree/11.1.WebHttpAPI/lecture/WebHttpAPI.ipynb#URL:-Uniform-Resource-Locator
# ```
#
# URI - более широкий класс, включающий URL и другие способы идентификации, например ISBN.

# %% [markdown]
# ## DNS: Domain Name System
#
# DNS — это распределённая система, которая переводит удобные для человека доменные имена в IP‑адреса, чтобы устройства могли находить и подключаться к нужным серверам без запоминания числовых адресов.
#
# <div><center>
# <img style="max-width: 800px"  src="./images/basics-of-dns-resolving-with-cache.jpg" />
#     <div><a href="https://www.ntchosting.com/encyclopedia/dns/dns-services/">image credit</a></div>
# </center></div>

# %%
import socket

socket.gethostbyname('ya.ru')

# %%
socket.getfqdn('5.255.255.242')

# %% [markdown]
# ## HTTP: HyperText Transfer Protocol
#
# - Протокол прикладного уровня (поверх TCP) на базе которого работают многие приложения
# - Есть несколько версий - [HTTP/1.1](https://www.rfc-editor.org/rfc/rfc9112), [HTTP/2](https://www.rfc-editor.org/rfc/rfc9113), [HTTP/3](https://www.rfc-editor.org/rfc/rfc9114)

# %% [markdown]
# ### HTTP Request
#
# <div><center>
# <img style="max-width: 800px" src="./images/HTTP_Request.png" />
#     <div><a href="https://bmeneg.com/posts/net-stack-app/">image credit</a></div>
# </center></div>

# %% [markdown]
# ### HTTP Methods
#
# <div><center>
# <img style="max-width: 800px" src="./images/HTTP_methods.jpg" />
#     <div><a href="https://rithikied.medium.com/basic-http-request-part-1-4d5dbf62272">image credit</a></div>
# </center></div>

# %% [markdown]
# ### HTTP Headers
#
# [Mozilla docs: list of HTTP headers](https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers)
#
#
# <div><center>
# <img style="max-width: 800px" src="./images/HTTP_Request_Headers2.png" />
#     <div><a href="https://www.catchpoint.com/blog/http-headers">image credit</a></div>
# </center></div>

# %% [markdown]
# ### HTTP Response
#
# <div><center>
# <img style="max-width: 800px" src="./images/HTTP_Response.png" />
#     <div><a href="https://bmeneg.com/posts/net-stack-app/">image credit</a></div>
# </center></div>

# %% [markdown]
# <div><center>
# <img style="max-width: 800px" src="./images/HTTP_Response_Headers2.png" />
#     <div><a href="https://itnext.io/some-structure-data-for-work-with-api-8e9f2816cd84">image credit</a></div>
# </center></div>

# %% [markdown]
# ### HTTP Status Codes
#
# [Mozilla docs: list of HTTP statuses](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status)
#
# <div><center>
# <img style="max-width: 800px" src="./images/HTTP_Status_Codes.png" />
#     <div><a href="https://javaconceptoftheday.com/http-status-codes-cheat-sheet/">image credit</a></div>
# </center></div>

# %% [markdown]
# # Сети в Python и Web Scraping

# %% [markdown]
# ## Low-level

# %% [markdown]
# ### [`socket`](https://docs.python.org/3/library/socket.html)

# %% [markdown]
# #### Send via UDP (ipv4)

# %%
addr = '127.0.0.1', 6001  # host, port

sock_one = socket.socket(
    socket.AF_INET,  # Address Family INET - IPv4
    socket.SOCK_DGRAM  # ≈ "use UDP"
)
sock_one.bind(addr)

with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as sock_two:
    sock_two.sendto(b'Hello,', addr)
    sock_two.sendto(b'world!', addr)

with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as sock_three:
    sock_three.sendto(b'How', addr)
    sock_three.sendto(b'are', addr)
    sock_three.sendto(b'you?', addr)

for _ in range(5):
    data, addr = sock_one.recvfrom(1024)
    print(f'From {addr[0]}:{addr[1]}: {data}')

sock_one.close()

# %% [markdown]
# #### Send via UDP (ipv6)

# %%
addr = '::1', 6002, 0, 0  # (address, port, flowinfo, scope_id)

sock_one = socket.socket(
    socket.AF_INET6,  # Address Family INET6 - IPv6
    socket.SOCK_DGRAM  # ≈ "use UDP"
)
sock_one.bind(addr)

with socket.socket(socket.AF_INET6, socket.SOCK_DGRAM) as sock_two:
    sock_two.sendto(b'Hello,', addr)
    sock_two.sendto(b'world!', addr)
    
with socket.socket(socket.AF_INET6, socket.SOCK_DGRAM) as sock_three:
    sock_three.sendto(b'How', addr)
    sock_three.sendto(b'are', addr)
    sock_three.sendto(b'you?', addr)

for _ in range(5):
    data, addr = sock_one.recvfrom(1024)
    print(f'From {addr}: {data}')

sock_one.close()

# %% [markdown]
# #### Send via TCP (ipv4)

# %%
addr = 'httpbin.org', 80

request = b'\r\n'.join([
    b'GET / HTTP/1.1',  # передаём HTTP запрос поверх TCP
    b'Host: httpbin.org',
    b'', 
    b''
])

with socket.socket(
    family=socket.AF_INET,  # Adress Family INET - IPv4
    type=socket.SOCK_STREAM  # ≈ "use TCP"
) as sock:
    sock.connect(addr)
    sock.sendall(request)
    response = sock.recv(1024)

# %%
print(response.decode('utf-8'))

# %% [markdown]
# #### Send via TCP (ipv6)
# (и немного HTTP)

# %%
socket.getaddrinfo('localhost', None)

# %%
addr = '::1', 8889, 0, 0  # localhost и 8889 порт на котором поднят Jupyter Notebook

request = b'\r\n'.join([
    b'GET /static/favicons/favicon.ico HTTP/1.1', 
    b'Host: ::1:8889', 
    b'', 
    b''  
])

with socket.socket(
    family=socket.AF_INET6,  # Adress Family INET6
    type=socket.SOCK_STREAM  # ≈ "use TCP"
) as sock:
    sock.connect(addr)
    sock.sendall(request)
    response = sock.recv(512)

print(response)

# %% [markdown]
# #### SSL / TLS

# %% [markdown]
# <div><center>
# <img style="max-width: 800px" src="./images/what-is-ssl-handshake.svg" />
#     <div><a href="https://www.manageengine.com/key-manager/information-center/what-is-ssl-certificate-management.html">image credit</a></div>
# </center></div>

# %%
request = b'\r\n'.join([
    b'GET /get HTTP/1.1',
    b'Host: httpbin.org',
    b'', 
    b''
])

with socket.create_connection(('httpbin.org', 443), timeout=1) as sock:  # 443 порт HTTPS
    sock.sendall(request)
    response = sock.recv(1024)
    
print(response.decode('utf8'))

# %%
import ssl
import certifi

context = ssl.create_default_context(cafile=certifi.where())

request = b'\r\n'.join([
    b'GET / HTTP/1.1',
    b'Host: httpbin.org',
    b'', 
    b''
])

with socket.create_connection(('httpbin.org', 443)) as sock:
    with context.wrap_socket(sock, server_hostname='httpbin.org') as ssock:
        ssock.sendall(request)
        response = ssock.recv(512)
    
print(response.decode('utf8'))

# %% [markdown]
# ### [`http`](https://docs.python.org/3/library/http.html)
#
# Встроенная библиотека для работы с HTTP с базовым функционалом

# %%
import http

# %%
host = "docs.python.org"

conn = http.client.HTTPSConnection(host, context=ssl.create_default_context(cafile=certifi.where()))
conn.request("GET", "/3/", headers={"Host": host})
response = conn.getresponse()

print(response.status, response.reason)

# %%
dir(http.HTTPStatus)[:30]

# %% [markdown]
# ## High-level

# %% [markdown]
# ### [`urllib`](https://docs.python.org/3/library/urllib.html)
#
# Полезные утилиты для работы с URL + возможность делать запросы

# %%
import urllib

with urllib.request.urlopen('http://www.python.org/', context=ssl.create_default_context(cafile=certifi.where())) as f:
    print(f.read(300))

# %%
url = "https://www.site.com/some/path/to/resource?query=1#fragment"

urllib.parse.urlsplit(url)  # input is not validated - users should validate themselves

# %%
sr = urllib.parse.urlsplit(url)
urllib.parse.urlunsplit((
    sr.scheme, sr.netloc.replace('.com', '.org'), sr.path, sr.query, sr.fragment
))

# %% [markdown]
# ### [Requests: HTTP for Humans](https://requests.readthedocs.io/en/latest/)
#
# Простая и удобная библиотека для работы с HTTP в python

# %%
import requests

response = requests.get('https://httpbin.org')

response.status_code

# %%
print(response.text[:512])

# %%
from pprint import pp

response = requests.head('http://httpbin.org')

pp(dict(response.headers))

# %%
response = requests.options('http://httpbin.org', timeout=5)

print(response.content)
pp(dict(response.headers))

# %%
response = requests.get('http://ya.ru/non/existing/path')

response.raise_for_status()

# %% [markdown]
# ### [httpx](https://www.python-httpx.org/)
#
# Мощная библиотека с множеством фичей и поддержкой синхронных и асинхронных запросов

# %%
import httpx

client = httpx.Client(base_url='http://httpbin.org')
client.get('/get').json()

# %%
async with httpx.AsyncClient(base_url='http://httpbin.org') as async_client: 
    res = (await async_client.get('/get')).json()
res

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# <b>HTML: HyperText Markup Language</b>
#
# <div><center>
# <img src="attachment:blogwork-HTML-tag-p-for-Beginner.png" />
#     <div><a href="https://blogwork.ru/wp-content/uploads/2016/08/blogwork-HTML-tag-p-for-Beginner.png">image credit</a></div>
# </center></div>

# %%
from bs4 import BeautifulSoup

# %%
html = requests.get('https://example.com', timeout=1).text

# %%
soup = BeautifulSoup(html)

# %%
css_element = soup.html.head.style
print(css_element)
css_element.clear()

# %%
print(soup.prettify()[:1000])

# %%
html = soup.html

# %%
html.head.title

# %%
html.head.findAll('meta')

# %%
paragraphs = html.findAll('p')
paragraphs

# %%
links = html.findAll('a')
links

# %%
for link in links:
    print(link.text, link['href'])

# %% [markdown]
# ### Scraping a real page
#
# <b>(!) парсить сайты - неблагодарное дело (!)</b>
#
# Сайты активно защищаются от автоматического скрапинга.

# %%
URL = 'https://en.wikipedia.org/wiki/Purchasing_power_parity'

response = requests.get(URL, timeout=5)

response.raise_for_status()

# %%
# !uv pip install fake-headers

# %%
from fake_headers import Headers

# %%
headers = Headers(browser='chrome', os='win', headers=True).generate()

# %%
headers

# %%
response = requests.get(URL, headers=headers, timeout=5)

response.raise_for_status()

# %%
soup = BeautifulSoup(response.text)

# %%
table = soup.find('table', attrs={'class': 'wikitable'})

table_headers = []
table_data = []

for row in table.findAll('tr'): 
    if row.find('th'): 
        for h in row.findAll('th'): 
            table_headers.append(h.text.strip())
    else: 
        table_data.append(tuple(map(lambda x: x.text.strip(), row.findAll('td'))))

# %%
import pandas as pd

df = pd.DataFrame(table_data, columns=table_headers)
df.head(10)

# %% [markdown]
# # API: Application Programming Interface
#
# API позволяют приложениям обмениваться информацией друг с другом

# %% [markdown]
# ## Немного теории

# %% [markdown]
# <b>REST</b> — архитектурный стиль (Representational State Transfer) для сетевого взаимодействия клиента и сервера; он задаёт ограничения, повышающие производительность, масштабируемость, простоту и надёжность.
#
# Ограничения REST:
#
# - Без состояния: сервер не хранит состояние между запросами.
# - Клиент–сервер: компоненты разделены и развиваются независимо.
# - Кэшируемость: ответы можно кэшировать на клиенте или сервере.
# - Унифицированный интерфейс: единый способ доступа к ресурсам, независимый от их представления.
# - Многоуровневость: возможны промежуточные слои (прокси, балансировщики).
#
# REST — не спецификация, а набор принципов/рекомендаций по архитектуре API.

# %% [markdown]
# <div><center>
# <img style="max-width: 800px" src="./images/rest.webp" width="800" />
#     <div><a href="https://dev.to/opman129/what-are-rest-apis-13c7">image credit</a></div>
# </center></div>

# %% [markdown]
# Многие API работают принимая и передавая данные в <b>JSON - JavaScript Object Notation</b>
#
# <div><center>
# <img style="max-width: 800px" src="./images/json-introduction.png" width="800" />
#     <div><a href="https://medium.com/@kells08/basics-of-json-6e492ed18520">image credit</a></div>
# </center></div>

# %% [markdown]
# ## Публичные API

# %% [markdown]
# ### API без авторизации

# %%
BASE_URL = 'https://jsonplaceholder.typicode.com'

resp = requests.get(BASE_URL + '/posts')
resp.json()[:5]

# %%
resp = requests.delete(BASE_URL + '/posts')
pp(dict(resp.headers))
resp.json()

# %%
# Data to be sent
data = {
    "userID": 1,
    "title": "Making a POST request",
    "body": "This is the data we created."
}

# A POST request to the API
response = requests.post(BASE_URL + '/posts', json=data)

# Print the response
print(response.json())
print(response.status_code)

# %%
todo = {"title": "Mow lawn"}

response = requests.patch(BASE_URL + '/todos/10', json=todo)

response.json()

# %%
# Реальное API - курсы валют

response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

response.json()

# %% [markdown]
# ### API с авторизацией

# %%
DICTIONARY_API = 'https://dictionary.yandex.net/api/v1/dicservice.json/lookup'
TEMP_KEY = 'dict.1.1.20191119T132629Z.f06d32fa3b4c5e18.922a67da8890eb40fb4a680a7d5d10347f8139b7'

params = {'key': TEMP_KEY, 'lang': 'en-ru', 'text': 'hello'}
response = requests.get(DICTIONARY_API, params=params, timeout=1)

response.raise_for_status()

body = response.text

print(response.headers['content-type'])

# %%
definition = response.json()['def'] # or json.loads(body)['def']

definition[:2]

# %%
from requests.auth import HTTPBasicAuth
from pathlib import Path

token = (Path.home() / '.shad/github.token').read_text().strip()

private_url = "https://api.github.com/user"
github_username = "zhukpm"

private_url_response = requests.get(
    url=private_url,
    auth=HTTPBasicAuth(github_username, token)
)

private_url_response.status_code

# %%
private_url_response.json()

# %%
private_url_response = requests.get(
    url="https://api.github.com/users/tiangolo",
    auth=HTTPBasicAuth(github_username, token)
)

print(private_url_response.status_code)
private_url_response.json()

# %% [markdown]
# ### API с OAuth авторизацией и python-клиент

# %% [markdown]
# OAuth токен можно полуить тут:
#
# https://oauth.yandex.ru/authorize?response_type=token&client_id=4bc448e01f46442883dce6dc3254e44c&device_id=my_device
#
# и положить в `~/.shad/yandex.http-lecture.token`

# %%
class YandexLoginClient:
    """Клиент для доступа к общей информации о профиле в Яндексе"""
    
    def __init__(self, *, base_url="https://login.yandex.ru", token):
        self._base_url = base_url
        self._session = requests.Session()
        self._session.headers['Authorization'] = f'OAuth {token}'
    
    def info(self):
        response = self._session.get(self._base_url + '/info', timeout=3)
        response.raise_for_status()
        return response.json()
    
    def censored_email(self):
        email = self.info()['default_email']
        name, host = email.split('@')
        return name[0] + '*' * (len(name) - 1) + '@' + host

# %%
yandex_token = (Path.home() / '.shad/yandex.http-lecture.token').read_text().strip()

client = YandexLoginClient(token=yandex_token)

# %%
client.censored_email()

# %% [markdown]
# ## Непубличное API

# %% [markdown]
# Любые WEB-приложения для обновления данных внутри себя ходят в какие-то внутренние API своей платформы. При некотором старании можно научиться пользоваться этими API в вашем коде. Впрочем, для непубличного API гарантий никаких – сломаться может в любой момент.

# %%
# fastapi dev simple_books_server.py

URL = 'http://127.0.0.1:8000'

# %%
resp = requests.get(URL + '/books')
resp.json()

# %%
resp = requests.post(URL + '/books', json={'title': 'Hello, world', 'author': 'The Best Man'})
res = resp.json()
added_book_id = res['id']
res

# %%
requests.get(URL + f'/books/{added_book_id}').json()

# %%
import json 

requests.patch(
    URL + f'/books/{added_book_id}', 
    data=json.dumps({'year': 2012}),
).json()

# %%
resp = requests.patch(URL + f'/books/{added_book_id}', json={'year': "asd"})
resp.status_code, resp.json()

# %%
resp = requests.patch(URL + '/books/79061d01-c1e3-4491-8001', json={})
resp.status_code, resp.json()
